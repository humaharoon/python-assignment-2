# %% [markdown]
# # Python assignment #2

# %% [markdown]
# ## Arthematic operator

# %% [markdown]
# ### sum of two number

# %%
a=10
b=6
c=a+b
print(c)
# Out:
# 16

# %% [markdown]
# ### Find reminder

# %%
a=24
b=14
print(a%b)
# Out:
# 10

# %% [markdown]
# ### the square of the number using the power operator

# %%
a=8
b=a**2
print(b)
# Out:
# 64

# %% [markdown]
# ## assignment operator

# %% [markdown]
# ### assign a value to a variable increases it by 5 using assignment operator

# %%
a=4
a+=5
print(a)
# Out:
# 9

# %% [markdown]
# ### multiplies a variable by 2 using an assignment operator

# %%
a=8
a*=2
print(a)
# Out:
# 16

# %% [markdown]
# ### subtracts 10 from a variable using an assignment operator

# %%
a=40
a-=10
print(a)
# Out:
# 30

# %% [markdown]
# ## comparison operator

# %% [markdown]
# ### two number are equal or not

# %%
a=3
b=8
a==b
# Out:
# False

# %%
a=6
b=6
a==b
# Out:
# True

# %% [markdown]
# ### one number is greater than other

# %%
a=60
b=20
a>b
# Out:
# True

# %% [markdown]
# ### one number is less than other

# %%
a=50
b=70
a<b
# Out:
# True

# %% [markdown]
# ## logical operator

# %% [markdown]
# ### check a number is greater than 5 and less than 20

# %%
a=6
a>5 & a<20
# Out:
# True

# %%
a=4
a>5 & a<20
# Out:
# False

# %% [markdown]
# ### check a number is less than 10 or greater than 20

# %%
a=7
a<10 or a>20
# Out:
# True

# %%
a=13
a<10 or a>20
# Out:
# False

# %% [markdown]
# ### uses the not operator

# %%
a=6
not a>5
# Out:
# False

# %%
a=4
not a>5
# Out:
# True

# %% [markdown]
# ## membership operator

# %% [markdown]
# ### check a number exist in a given list

# %%
numbers = [1,3,7,9]
3 in numbers
# Out:
# True

# %%
number = [5,9,7,2]
1 in number
# Out:
# False

# %% [markdown]
# ### check a word exist in given list

# %%
words = ["good","best","better"]
"good" in words
# Out:
# True

# %%
words = ["good","best","better"]
"excellent" in words
# Out:
# False

# %% [markdown]
# ### check a value is present in a tuple

# %%
numbers = (1,6,9,3,6,5)
10  not in numbers
# Out:
# True
